# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("D:\labs\data_set\Marathon.csv")
df
# Out:
#      Year     Minutes
# 0    1897  175.166667
# 1    1898  162.000000
# 2    1899  174.633333
# 3    1900  159.733333
# 4    1901  149.383333
# ..    ...         ...
# 115  2012  132.666667
# 116  2013  130.366667
# 117  2014  128.616667
# 118  2015  129.283333
# 119  2016  132.733333
#
# [120 rows x 2 columns]

# %%
x=df['Year']
y=df['Minutes']

# %%
plt.plot(x,y)

# %%
m, c = np.polyfit(x, y, 1)

# %%
print(f"The slope is {m:.2f}")
print(f"The intercept is {c:.2f}")
# Out:
# The slope is -0.29
# The intercept is 713.98

# %%
y_pred = m * x + c

# %%
x = np.array(df['Year'])
y = np.array(df['Minutes'])

plt.plot(x, y, color='purple')
plt.plot(x, y_pred, color='green')
plt.show()

# %%
residuals = y - y_pred

plt.figure(figsize=(10, 6))
plt.scatter(x, residuals, color='purple')
plt.axhline(y=0, color='green', linestyle='--', linewidth=1)
plt.title('Residuals vs Year')
plt.xlabel('Year')
plt.ylabel('Residuals')
plt.show()

# %%
x = 2020
y_pred = m * x + c

print("winning time for the men’s 400 meters final in the 2020 Olympics ", y_pred)
# Out:
# winning time for the men’s 400 meters final in the 2020 Olympics  123.49378676231106
